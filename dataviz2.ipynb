# %%
import torch

import seaborn as sns
import matplotlib.pyplot as plt

from data import GODData
from torchvision.transforms import ToTensor

# %%
def data_transform(x):
    x = torch.tensor(x, dtype=torch.float32) # convert to tensor
    x = x / x.max() # normalize
    return x

train_dataset = GODData(subject="01", session_id="01", task="perception", train=True, transform=data_transform)

# %%
for f, l in train_dataset:
    plt.figure(figsize=(10, 10))
    for slidx in range(f.shape[1]):
        plt.subplot(8, 8, slidx + 1)
        plt.imshow(f[1, slidx, :, :], cmap="seismic")/home2/vishva.saravanan/projects/ViT-fMRI/lightning.ipynb
        plt.axis("off")
    plt.tight_layout()
    plt.show()
    break
